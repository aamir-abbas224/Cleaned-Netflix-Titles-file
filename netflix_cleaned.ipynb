# %%
import pandas as pd


df = pd.read_csv('netflix_titles.csv')

df

# %%
df.dropna(inplace=True)
df.drop_duplicates(inplace=True)

# %%
df
# Out:
#                               show_id     type             director  \
# title
# Sankofa                            s8    Movie         Haile Gerima
# The Great British Baking Show      s9  TV Show      Andy Devonshire
# The Starling                      s10    Movie       Theodore Melfi
# Je Suis Karl                      s13    Movie  Christian Schwochow
# Jeans                             s25    Movie           S. Shankar
# ...                               ...      ...                  ...
# Zinzana                         s8802    Movie      Majid Al Ansari
# Zodiac                          s8803    Movie        David Fincher
# Zombieland                      s8805    Movie      Ruben Fleischer
# Zoom                            s8806    Movie         Peter Hewitt
# Zubaan                          s8807    Movie          Mozez Singh
#
#                                                                             cast  \
# title
# ...
